# %%
import MM1Sever
import numpy as np

def mm1():
    # 在这改参数
    lam = 0.09 # λ
    mu = 0.1 # μ
    rou = lam/mu
    E_N = rou/(1-rou)
    T = 1/(mu-lam)

    cacheLengthList = []
    waitingTimeList = []

    print("理论值\nλ:%f\nμ:%f\nrou:%f\nE[N]:%f\nT:%f"%(lam,mu,rou,E_N,T))

    # 多次实验取平均
    for i in range(50):

        sever = MM1Sever.Sever(lam,1/mu,5000,False,[])

        sever.startSimulation()

        cacheLength,waitingTime = sever.statistics()
        cacheLengthList.append(cacheLength)
        waitingTimeList.append(waitingTime)

        print("平均队长:%.3f\t平均等待时间:%.3f"%(cacheLength,waitingTime))
    
    print("\n\n经过多次实验求平均后：")
    print("平均队长：% .3f"%np.mean(cacheLengthList))
    print("平均等待时间：% .3f"%np.mean(waitingTimeList))


def _2_mm1():
    # 在这改参数
    lam = 0.09 # λ
    mu_1 = 0.1
    mu_2 = 0.1

    T = 1/(mu_1-lam)+1/(mu_2-lam)

    # cacheLengthList = []
    waitingTimeList = []

    print("理论值\nλ:%f\nμ1:%f\nμ2:%f\nT:%f"%(lam,mu_1,mu_2,T))




    # 多次实验取平均
    for i in range(50):

        # mm1
        sever = MM1Sever.Sever(lam,1/mu_1,5000,False,[])
        sever.startSimulation()
     
        cacheLength,waitingTime_1 = sever.statistics()
        # cacheLengthList.append(cacheLength)      
        # print(sever.finishServicingTime)

        # 第二个mm1

        a = sever.finishServicingTime
        b=[]
        for i in range(len(a)):
            b.append(np.array(a[i]))
        c=np.array(b)
        sever_2 = MM1Sever.Sever(lam,1/mu_2,5000,True,c)
        sever_2.startSimulation()
        cacheLength,waitingTime_2 = sever.statistics()
        waitingTime = waitingTime_1+waitingTime_2
        waitingTimeList.append(waitingTime)

        print("平均等待时间:%.3f"%(waitingTime))

    print("\n\n经过多次实验求平均后：")
    print("平均等待时间：% .3f"%np.mean(waitingTimeList))

# %%
mm1()
# Out:
# 理论值
# λ:0.090000
# μ:0.100000
# rou:0.900000
# E[N]:9.000000
# T:100.000000
# 平均队长:11.479	平均等待时间:118.832
# 平均队长:5.187	平均等待时间:60.885
# 平均队长:4.199	平均等待时间:48.828
# 平均队长:9.531	平均等待时间:101.608
# 平均队长:8.764	平均等待时间:97.166
# 平均队长:21.315	平均等待时间:216.616
# 平均队长:5.227	平均等待时间:57.570
# 平均队长:15.083	平均等待时间:159.778
# 平均队长:4.448	平均等待时间:52.950
# 平均队长:10.514	平均等待时间:109.517
# 平均队长:5.376	平均等待时间:61.370
# 平均队长:11.415	平均等待时间:123.805
# 平均队长:8.293	平均等待时间:89.946
# 平均队长:9.803	平均等待时间:98.222
# 平均队长:6.382	平均等待时间:69.525
# 平均队长:4.680	平均等待时间:55.845
# 平均队长:5.930	平均等待时间:66.329
# 平均队长:7.282	平均等待时间:78.976
# 平均队长:9.400	平均等待时间:98.735
# 平均队长:8.112	平均等待时间:93.459
# 平均队长:9.959	平均等待时间:105.720
# 平均队长:7.178	平均等待时间:78.706
# 平均队长:8.496	平均等待时间:94.186
# 平均队长:14.641	平均等待时间:149.090
# 平均队长:9.992	平均等待时间:109.802
# 平均队长:5.847	平均等待时间:65.111
# 平均队长:7.187	平均等待时间:83.178
# 平均队长:18.348	平均等待时间:204.318
# 平均队长:3.734	平均等待时间:46.096
# 平均队长:2.066	平均等待时间:24.593
# 平均队长:7.964	平均等待时间:87.512
# 平均队长:5.256	平均等待时间:61.541
# 平均队长:4.438	平均等待时间:48.771
# 平均队长:4.597	平均等待时间:54.601
# 平均队长:4.424	平均等待时间:50.502
# 平均队长:12.180	平均等待时间:140.647
# 平均队长:20.713	平均等待时间:224.653
# 平均队长:8.899	平均等待时间:99.537
# 平均队长:35.876	平均等待时间:368.333
# 平均队长:11.930	平均等待时间:135.573
# 平均队长:5.793	平均等待时间:65.979
# 平均队长:26.009	平均等待时间:262.188
# 平均队长:5.255	平均等待时间:57.499
# 平均队长:25.355	平均等待时间:267.456
# 平均队长:7.428	平均等待时间:83.837
# 平均队长:15.186	平均等待时间:156.876
# 平均队长:11.501	平均等待时间:126.103
# 平均队长:14.671	平均等待时间:154.107
# 平均队长:4.056	平均等待时间:46.191
# 平均队长:5.334	平均等待时间:63.959
#
#
# 经过多次实验求平均后：
# 平均队长： 9.935
# 平均等待时间： 107.533

# %%
_2_mm1()
# Out:
# 理论值
# λ:0.090000
# μ1:0.100000
# μ2:0.100000
# T:200.000000
# 平均等待时间:43.124
# 平均等待时间:268.209
# 平均等待时间:41.292
# 平均等待时间:268.265
# 平均等待时间:317.367
# 平均等待时间:195.595
# 平均等待时间:510.524
# 平均等待时间:75.366
# 平均等待时间:145.438
# 平均等待时间:431.794
# 平均等待时间:144.253
# 平均等待时间:108.950
# 平均等待时间:130.427
# 平均等待时间:67.625
# 平均等待时间:195.352
# 平均等待时间:125.499
# 平均等待时间:460.270
# 平均等待时间:383.097
# 平均等待时间:104.890
# 平均等待时间:185.365
# 平均等待时间:173.236
# 平均等待时间:263.550
# 平均等待时间:205.013
# 平均等待时间:157.832
# 平均等待时间:441.784
# 平均等待时间:373.591
# 平均等待时间:193.451
# 平均等待时间:301.970
# 平均等待时间:407.342
# 平均等待时间:125.063
# 平均等待时间:343.991
# 平均等待时间:195.264
# 平均等待时间:374.987
# 平均等待时间:493.078
# 平均等待时间:192.584
# 平均等待时间:81.360
# 平均等待时间:549.078
# 平均等待时间:309.854
# 平均等待时间:184.973
# 平均等待时间:222.283
# 平均等待时间:169.275
# 平均等待时间:177.615
# 平均等待时间:486.514
# 平均等待时间:216.752
# 平均等待时间:82.082
# 平均等待时间:236.443
# 平均等待时间:278.237
# 平均等待时间:117.714
# 平均等待时间:158.662
# 平均等待时间:152.939
#
#
# 经过多次实验求平均后：
# 平均等待时间： 237.384
