# %%
import MM1Sever

lam = 0.2
mu = 0.4
rou = lam/mu
E_N = rou/(1-rou)
T = 1/(mu-lam)


sever = MM1Sever.Sever(lam,1/mu,10000)

sever.startSimulation()

print("理论值\nλ:%f\nμ:%f\nrou:%f\nE[N]:%f\nT:%f"%(lam,mu,rou,E_N,T))

sever.statistics()
# Out:
# 顾客数量为 2097
# 到达时间 | 服务时间
#        0 |       5
#        2 |       1
#        9 |       4
#       13 |       6
#       15 |       2
#       16 |       2
#       19 |       2
#       33 |       1
#       37 |       1
#       41 |       4
#       46 |       4
#       49 |       4
#       49 |       7
#       54 |       2
#       55 |       2
#       56 |       1
#       57 |       1
#       58 |       3
#       61 |       2
#       73 |       3
#       79 |       1
#       80 |       1
#       80 |       6
#       81 |       1
#       86 |       1
#       92 |      10
#      107 |       3
#      109 |       3
#      114 |       4
#      124 |       2
#      131 |       2
#      132 |       1
#      145 |       4
#      153 |       2
#      158 |       3
#      161 |       3
#      164 |       7
#      165 |       7
#      166 |       3
#      168 |       1
#      168 |       3
#      169 |       9
#      175 |       6
#      176 |       1
#      177 |       1
#      179 |       2
# ...
